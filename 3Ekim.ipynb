# %%
def inverse(pixel):
    return 255-pixel

# %%
m=img_1.shape[0]
n=img_1.shape[1]

print(m,n)

for i in range(m):
  for j in range(n):
    img_2[i,j,0] = inverse (img_1[i,j,0])
    img_2[i,j,1] = inverse (img_1[i,j,1])
    
imshow(img_2)
# Out:
# 768 1024

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import imshow

img_1=plt.imread("img_1.jpg")
img_2=plt.imread("img_1.jpg")
# %matplotlib inline

imshow(img_1)

# %%
def my_H(image):
  Hash= {}
    
  m = image.shape[0]
  n = image.shape[1]
  for i in range(256):
     Hash[i]=0
        
  for i in range (m):
    for j in range (n):
        Hash[image[i,j,0]] += 1
        Hash[image[i,j,1]] += 1
        Hash[image[i,j,1]] += 1
